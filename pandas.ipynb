# %% [markdown]
# ## Часть 1: Введение в Pandas
#
# Pandas - это библиотека Python для работы с данными. Она предоставляет мощные инструменты для анализа и манипуляции данными.
#
# ### Установка Pandas
#
# Для начала убедитесь, что у вас установлена библиотека Pandas. Если ее нет, установите ее с помощью команды:

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Импорт библиотеки
# Давайте начнем с импорта библиотеки Pandas:

# %%
import pandas as pd

# %% [markdown]
# ## Часть 2: Работа с данными
# ### Чтение данных
# Мы будем использовать датасет Titanic. Давайте прочитаем данные из CSV файла.

# %%
df = pd.read_csv('titanic.csv')

# %% [markdown]
# ### Предпросмотр данных
# Для первого ознакомления с данными давайте выведем первые несколько строк.

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Информация о данных
# Чтобы получить общую информацию о данных, воспользуйтесь методом .info().

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %% [markdown]
# ### Работа с NaN
# Часто данные содержат пропущенные значения, которые представляются как NaN (Not a Number). Pandas предоставляет удобные методы для работы с ними.
#
# Проверка на наличие NaN. Методы fillna и dropna возвращают новые Dataframe, проверьте нет ли в них NaN

# %%
# проверка на наличие NaN: возвращает df из булевых значений (True = NaN)
df.isna()

# смотрим итог пропусков по каждому столбцу
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Заполнение NaN

# %%
# заполняем все пропущенные значения нулями и сохраняем в новый DataFrame
df_filled = df.fillna(0)

# проверка на пропуски
df_filled.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# Удаление строк с NaN

# %%
# удаляем строки, содержащие хотя бы одно NaN
df_dropped = df.dropna()

# проверка на пропуски
df_dropped.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# ## Часть 3: Обработка DataFrame
# ### Выбор данных
# Pandas позволяет выбирать данные по индексам, меткам столбцов и условиям.

# %%
# выбор одного столбца по метке - возвращает Series
df['Age']

# выбор нескольких столбцов  возвращает DataFrame
df[['Name', 'Age', 'Survived']]

# выбор строк по индексу (строки с 0 по 4 включительно)
df.loc[0:4]

# фильтр - оставляем только мужчин старше 30 лет
df[(df['Sex'] == 'male') & (df['Age'] > 30)]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 4              5         0       3              Allen, Mr. William Henry
# 6              7         0       1               McCarthy, Mr. Timothy J
# 13            14         0       3           Andersson, Mr. Anders Johan
# 20            21         0       2                  Fynney, Mr. Joseph J
# 21            22         1       2                 Beesley, Mr. Lawrence
# ..           ...       ...     ...                                   ...
# 867          868         0       1  Roebling, Mr. Washington Augustus II
# 872          873         0       1              Carlsson, Mr. Frans Olof
# 873          874         0       3           Vander Cruyssen, Mr. Victor
# 881          882         0       3                    Markun, Mr. Johann
# 890          891         0       3                   Dooley, Mr. Patrick
#
#       Sex   Age  SibSp  Parch    Ticket     Fare        Cabin Embarked
# ...

# %% [markdown]
# ### Сортировка данных
# Сортировка данных по значениям столбцов.

# %%
# сортировка по столбцу 'Age' по возрастанию
df.sort_values('Age')
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 803          804         1       3           Thomas, Master. Assad Alexander
# 755          756         1       2                 Hamalainen, Master. Viljo
# 644          645         1       3                    Baclini, Miss. Eugenie
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 78            79         1       2             Caldwell, Master. Alden Gates
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %% [markdown]
# ### Группировка данных
# Pandas также позволяет группировать данные и выполнять агрегирующие операции.

# %%
# группируем по классу (Pclass) и считаем долю выживших (среднее от 0/1)
df.groupby('Pclass')['Survived'].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %% [markdown]
# ## Часть 4: Задания для практики
# Прочитайте данные из файла 'titanic.csv'.
# Проверьте, есть ли пропущенные значения в данных и заполните их нулями.
# Выведите первые 10 строк данных.
# Выберите только те строки, где значение в столбце 'Age' больше 30.
# Отсортируйте данные по столбцу 'Fare' в порядке убывания.
# Сгруппируйте данные по столбцу 'Pclass' и вычислите средний возраст ('Age') для каждого класса.

# %%
df = pd.read_csv('titanic.csv')

# проверка на пропуски, если есть - заполняем нулями
print("Пропуски до заполнения:")
print(df.isna().sum())
df = df.fillna(0)
print("\nПропуски после заполнения:")
print(df.isna().sum())

# первые 10 строк
print(df.head(10))

# значение в столбце 'Age' больше 30
print(df[df['Age'] > 30])

# сортировка по Fare по убыванию
print(df.sort_values('Fare', ascending=False))

# средний возраст по классу
print(df.groupby('Pclass')['Age'].mean())
# Out:
# Пропуски до заполнения:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
#
# Пропуски после заполнения:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
# ...
